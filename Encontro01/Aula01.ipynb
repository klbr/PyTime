# %% [markdown]
# ## Inicio de todo programador!

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# ## Prototipagem simples

# %%
print('Calculadora de Juros:')

investimento = float(input('Investimento Inicial ? '))
taxa_juros = float(input('Taxa de Juros ? '))
anos = int(input('Duração (numero de anos) ? '))

total = (investimento * pow(1 + (taxa_juros/100), anos))
juros = total - investimento
print('\nJuros = %0.2f' % juros)
# Out:
# Calculadora de Juros:
# Investimento Inicial ? 5000
# Taxa de Juros ? 10
# Duração (numero de anos) ? 10
#
# Juros = 7968.71

# %% [markdown]
# ## Manipular XLSX

# %%
from openpyxl import Workbook
wb = Workbook()

# grab the active worksheet
ws = wb.active

# Data can be assigned directly to cells
ws['A1'] = 42

# Rows can also be appended
ws.append([1, 2, 3])

# Python types will automatically be converted
import datetime
ws['A2'] = datetime.datetime.now()

# Save the file
wb.save("sample.xlsx")

# %%
from openpyxl import load_workbook

# %%
wb2 = load_workbook('SAV.xlsx')
# Out:
# Wall time: 0 ns

# %%
# %time
ws = wb2.worksheets[0]
for row in ws.iter_rows():
    print([row[col].value if row[col].value else '' for col in range(10)])
# Out:
# Wall time: 0 ns
# ['Relatório do Coordenador - Avaliação Acadêmica', '', '', '', '', '', '', '', '', '']
# ['Classificação                                                                                           |                                                       Notas TRI', '', '', '', '', '', '', '', '', '']
# ['Escola', 'Nacional', 'Aluno', 'Turno', 'Turma', 'LCT', 'CHT', 'CNT', 'MT', 'Média']
# ['1º', '2º', 'ISAAC CAMILO GONZAGA', 'M', 'D', 796.05, 837.21, 918.38, 947.91, 874.89]
# ['2º', '10º', 'FELIPE SANCHEZ OTERO SANTOS', 'M', 'E', 749.73, 837.21, 891.79, 831.11, 827.46]
# ['3º', '19º', 'GUSTAVO DANTAS NUNES', 'M', 'E', 732.77, 806.0, 873.07, 825.21, 809.26]
# ['4º', '26º', 'AMANDA HELENA ALMEIDA MENESES', 'M', 'E', 746.8, 867.31, 854.56, 732.54, 800.3]
# ['5º', '30º', 'JOÃO GABRIEL DOS SANTOS OLIVEIRA', 'M', 'B', 686.73, 867.31, 818.99, 789.75, 790.7]
# ['6º', '32º', 'SAMARA EMANUELLE XAVIER DE OLIVEIRA', 'M', 'B', 688.23, 803.69, 826.61, 833.98, 788.13]
# ...

# %% [markdown]
# ## Usando Pandas

# %%
import pandas as pd

# %%
sav_excel = pd.read_excel('SAV.xlsx')
# Out:
# Wall time: 0 ns

# %%
sav_excel
# Out:
# Wall time: 0 ns
#         Relatório do Coordenador - Avaliação Acadêmica Unnamed: 1  \
# 0    Classificação                                 ...        NaN
# 1                                               Escola   Nacional
# 2                                                   1º         2º
# 3                                                   2º        10º
# 4                                                   3º        19º
# 5                                                   4º        26º
# 6                                                   5º        30º
# 7                                                   6º        32º
# 8                                                   7º        33º
# 9                                                   8º        50º
# 10                                                  9º        63º
# 11                                                 10º        93º
# 12                                                 11º        94º
# ...

# %%
sav_excel.head()
# Out:
#       Relatório do Coordenador - Avaliação Acadêmica Unnamed: 1  \
# 0  Classificação                                 ...        NaN
# 1                                             Escola   Nacional
# 2                                                 1º         2º
# 3                                                 2º        10º
# 4                                                 3º        19º
#
#                     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                          NaN        NaN        NaN        NaN        NaN
# 1                        Aluno      Turno      Turma        LCT        CHT
# 2         ISAAC CAMILO GONZAGA          M          D     796.05     837.21
# 3  FELIPE SANCHEZ OTERO SANTOS          M          E     749.73     837.21
# 4         GUSTAVO DANTAS NUNES          M          E     732.77        806
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN        NaN        NaN
# 1        CNT         MT      Média
# ...

# %%
sav_excel.tail()
# Out:
#     Relatório do Coordenador - Avaliação Acadêmica Unnamed: 1  \
# 158                                           157º      9393º
# 159                                           158º      9456º
# 160                                           159º      9837º
# 161                                           160º     11117º
# 162                                           161º     11537º
#
#                         Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 158   MATHEUS CORREIA HORA BRANDÃO          M          A     473.88
# 159      LAURA DELLE VEDOVE LEVITA          M          A     438.66
# 160        MARCELO LIMA DIAS FILHO          M          C      435.3
# 161             LARISSA LIMA SALES          M          D     438.69
# 162  ARTUR KOSZMA DE SOUZA BISNETO          M          A     477.33
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 158     343.67     386.96     508.11     428.16
# 159     391.76     497.76     380.28     427.12
# ...

# %%
sav_excel.columns
# Out:
# Index(['Relatório do Coordenador - Avaliação Acadêmica', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
sav_excel.columns = ['Rank_Nacional', 'Rank_Escola', 'Aluno', 'Turno', 'Turma', 'LCT', 'CHT', 'CNT', 'MT', 'Media']

# %%
sav_excel
# Out:
#                                          Rank_Nacional Rank_Escola  \
# 0    Classificação                                 ...         NaN
# 1                                               Escola    Nacional
# 2                                                   1º          2º
# 3                                                   2º         10º
# 4                                                   3º         19º
# 5                                                   4º         26º
# 6                                                   5º         30º
# 7                                                   6º         32º
# 8                                                   7º         33º
# 9                                                   8º         50º
# 10                                                  9º         63º
# 11                                                 10º         93º
# 12                                                 11º         94º
# ...

# %%
sav_excel.index[[0,1]]
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
sav_excel.drop(sav_excel.index[[0,1]], inplace=True)

# %%
sav_excel.head()
# Out:
#   Rank_Nacional Rank_Escola                             Aluno Turno Turma  \
# 2            1º          2º              ISAAC CAMILO GONZAGA     M     D
# 3            2º         10º       FELIPE SANCHEZ OTERO SANTOS     M     E
# 4            3º         19º              GUSTAVO DANTAS NUNES     M     E
# 5            4º         26º     AMANDA HELENA ALMEIDA MENESES     M     E
# 6            5º         30º  JOÃO GABRIEL DOS SANTOS OLIVEIRA     M     B
#
#       LCT     CHT     CNT      MT   Media
# 2  796.05  837.21  918.38  947.91  874.89
# 3  749.73  837.21  891.79  831.11  827.46
# 4  732.77     806  873.07  825.21  809.26
# 5   746.8  867.31  854.56  732.54   800.3
# 6  686.73  867.31  818.99  789.75   790.7

# %%
sav_excel['LCT'].mean()
# Out:
# 587.9321739130432

# %%
sav_excel['LCT'].std()
# Out:
# 88.68562197938043

# %%
sav_excel['LCT'].max(), sav_excel['LCT'].min()
# Out:
# (796.05, 366.19)

# %%
sav_excel['LCT'].mean(), sav_excel['LCT'].std(), sav_excel['LCT'].max(), sav_excel['LCT'].min()
# Out:
# (587.9321739130432, 88.68562197938043, 796.05, 366.19)
